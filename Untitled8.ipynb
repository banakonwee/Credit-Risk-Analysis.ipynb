# %% [markdown]
# <a href="https://colab.research.google.com/github/banakonwee/Credit-Risk-Analysis.ipynb/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# Import the pandas library
import pandas as pd

# Define the credit products data as a list of dictionaries
credit_products = [
    {"ProductID": 1, "ProductName": "Overdraft Facility", "ProductCategory": "Facility"},
    {"ProductID": 2, "ProductName": "Merchandise Loan Facility", "ProductCategory": "Loan"},
    {"ProductID": 3, "ProductName": "Warehouse Receipt Financing", "ProductCategory": "Loan"},
    {"ProductID": 4, "ProductName": "Import Letter of Credit Facility", "ProductCategory": "Facility"},
    {"ProductID": 5, "ProductName": "Back-to-Back Letters of Credit Financing", "ProductCategory": "Facility"},
    {"ProductID": 6, "ProductName": "Pre-shipment Export Credit Facility", "ProductCategory": "Loan"},
    {"ProductID": 7, "ProductName": "Pre-Shipment Export Credit for Trading Export Business", "ProductCategory": "Loan"},
    {"ProductID": 8, "ProductName": "Pre-Shipment Export Credit for Manufacturer-Exporters", "ProductCategory": "Loan"},
    {"ProductID": 9, "ProductName": "Contract-Based Channel Financing", "ProductCategory": "Loan"},
    {"ProductID": 10, "ProductName": "Livestock Export Financing", "ProductCategory": "Loan"},
    {"ProductID": 11, "ProductName": "Agricultural Output Financing", "ProductCategory": "Loan"},
    {"ProductID": 12, "ProductName": "Letter of Guaranty Facility", "ProductCategory": "Facility"},
    {"ProductID": 13, "ProductName": "Term Loan", "ProductCategory": "Loan"},
    {"ProductID": 14, "ProductName": "Motor Vehicle Loan", "ProductCategory": "Loan"},
    {"ProductID": 15, "ProductName": "Motor Vehicle Loan for Exporters", "ProductCategory": "Loan"},
    {"ProductID": 16, "ProductName": "Construction Machinery Loan", "ProductCategory": "Loan"},
    {"ProductID": 17, "ProductName": "Special Construction Machinery and Dump Truck Loan", "ProductCategory": "Loan"},
    {"ProductID": 18, "ProductName": "Infrastructure Construction Term Loan", "ProductCategory": "Loan"},
    {"ProductID": 19, "ProductName": "Investment Financing for Enterprises in Industrial Parks", "ProductCategory": "Loan"},
    {"ProductID": 20, "ProductName": "Partial Financing", "ProductCategory": "Loan"},
    {"ProductID": 21, "ProductName": "Syndicate Loan", "ProductCategory": "Loan"},
    {"ProductID": 22, "ProductName": "Agricultural Term Loan", "ProductCategory": "Loan"},
    {"ProductID": 23, "ProductName": "Micro-Finance Institution's Loan", "ProductCategory": "Loan"},
    {"ProductID": 24, "ProductName": "Channel Financing", "ProductCategory": "Loan"},
    {"ProductID": 25, "ProductName": "Urban Utilities Financing", "ProductCategory": "Loan"},
    {"ProductID": 26, "ProductName": "Consulting Firm Financing", "ProductCategory": "Loan"},
    {"ProductID": 27, "ProductName": "Inter-Bank Lending", "ProductCategory": "Loan"},
    {"ProductID": 28, "ProductName": "Idea Financing", "ProductCategory": "Loan"},
    {"ProductID": 29, "ProductName": "Import Letter of Credit Settlement Loan", "ProductCategory": "Loan"},
    {"ProductID": 30, "ProductName": "Loan Buyout", "ProductCategory": "Loan"},
    {"ProductID": 31, "ProductName": "Housing Development Loan", "ProductCategory": "Loan"},
    {"ProductID": 32, "ProductName": "Loan against Corporate (Coupon or Term) Bond", "ProductCategory": "Loan"},
    {"ProductID": 33, "ProductName": "Lease Financing", "ProductCategory": "Facility"}
]

# Convert the list of dictionaries into a Pandas DataFrame
credit_products_df = pd.DataFrame(credit_products)

# Display the DataFrame
print("Bank Credit Products Table:")
credit_products_df
# Out:
# Bank Credit Products Table:
#     ProductID                                        ProductName  \
# 0           1                                 Overdraft Facility
# 1           2                          Merchandise Loan Facility
# 2           3                        Warehouse Receipt Financing
# 3           4                   Import Letter of Credit Facility
# 4           5           Back-to-Back Letters of Credit Financing
# 5           6                Pre-shipment Export Credit Facility
# 6           7  Pre-Shipment Export Credit for Trading Export ...
# 7           8  Pre-Shipment Export Credit for Manufacturer-Ex...
# 8           9                   Contract-Based Channel Financing
# 9          10                         Livestock Export Financing
# 10         11                      Agricultural Output Financing
# 11         12                        Letter of Guaranty Facility
# 12         13                                          Term Loan
# ...

# %% [markdown]
# [link text](ht
#
# ```
# # This is formatted as code
# ```
#
# tps://)

# %%
credit_products_df = pd.DataFrame(credit_products)
